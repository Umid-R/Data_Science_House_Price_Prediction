# %%
import seaborn as sn
import pandas as pd

# %%
df=pd.read_csv('../Datasets/cleaned_data.csv')

# %%
# Number of total unique cities
df['city'].nunique()
# Out:
# 44

# %%
# Average number of rooms
df['bedrooms'].mean()
# Out:
# np.float64(3.4008695652173913)
